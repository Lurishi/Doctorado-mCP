# %% [markdown]
# # **The horrors of Meson decay mCP**

# %% [markdown]
# Para hallar el flujo de mCP en el canal de MD tenemos que calcular $d\Phi _\chi/dE_\chi$, que en el caso de meson decay, se puede hallar como:
#
# ![image.png](attachment:image.png)
#
# con $dn/dE_\chi$:
#
# ![image-2.png](attachment:image-2.png)
#
# Esta cantidad se calcula de distinta manera dependiendo del mesón padre, como se ve en el paper de mCP from the heavens, así que este notebook va a estar dividido en principio en esas dos partes :).

# %% [markdown]
# ## Mesones vectoriales
# Los mesones vectoriales resultan en decaimientos de dos cuerpos, en particular, el que nos interesaría es:
#
# $$Br(\textbf{m}\longrightarrow \chi \bar{\chi})$$
#
# El cual vamos a considerar que es proporcional a la branching fraction del mismo proceso pero generando un par electrón positrón.
#
# ![image.png](attachment:image.png)
#
# Con $I^{(2)}$
#
# ![image-2.png](attachment:image-2.png)
